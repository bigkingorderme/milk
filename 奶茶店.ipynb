# %%
import requests
import pandas as pd
import json
import numpy as np
import time

# %%
df = pd.read_excel('datafile.xlsx','utf-8-sig')
df.shape
# Out:
# (3267, 11)

# %%
df_city_20 = df.groupby(by='city')['nearbyStoreCount'].agg(['mean','count']).sort_values(by='count',ascending=False)[:20]
df_city_20
# Out:
#             mean  count
# city
# 上海市    65.500000    342
# 杭州市    64.158120    234
# 广州市   135.513761    218
# 宁波市   107.847458    177
# 深圳市   139.046243    173
# 南京市    84.006579    152
# 苏州市    50.958333    144
# 成都市   116.569444    144
# 福州市    77.015152    132
# 武汉市    93.548387    124
# 北京市    50.237705    122
# 无锡市    51.262712    118
# 长沙市    83.961165    103
# 重庆市   142.800000     80
# 合肥市    61.089286     56
# 青岛市    67.720000     50
# 温州市    71.021277     47
# 南通市    49.155556     45
# 金华市   117.636364     44
# 常州市    74.300000     40

# %%
# 可视化分析

from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.globals import ThemeType
from pyecharts.commons.utils import JsCode

bar = (Bar(init_opts=opts.InitOpts(theme='dark', width=400,
                                   bg_color={"type": "pattern", "image": JsCode("img"), "repeat": "no-repeat",}
                                  ))
            .add_xaxis(df_city_20.index.tolist())
            .add_yaxis("周边冷饮店数量", df_city_20['mean'].tolist())
            .add_yaxis("城市门店数量", df_city_20['count'].tolist(),color='yellow')
            .set_series_opts(label_opts=opts.LabelOpts(is_show=False, 
                                                       position='insideRight',
                                                       font_style='italic'),
                            
                            )
            .set_global_opts(
                title_opts=opts.TitleOpts(title="1点点门店最多20个城市与周边冷饮店数量",
                                         subtitle='数据截止日期：2020年8月'),
                xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=45)),
                legend_opts=opts.LegendOpts(is_show=True))
            
        )
bar.add_js_funcs(
    """
    var img = new Image(); img.src = 'https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1597303589545&di=fa120645101be97041050aeccd55253b&imgtype=0&src=http%3A%2F%2Fbpic.588ku.com%2Fback_pic%2F00%2F09%2F47%2F77562eea631a31c.jpg';
    """
)
bar.render_notebook()
# Out:
# D:\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="aa8f52164be04b8f8044948b400d4a71" style="width:400; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aa8f52164be04b8f8044948b400d4a71 = echarts.init(
#                     document.getElementById('aa8f52164be04b8f8044948b400d4a71'), 'dark', {renderer: 'canvas'});
#
#     var img = new Image(); img.src = 'https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1597303589545&di=fa120645101be97041050aeccd55253b&imgtype=0&src=http%3A%2F%2Fbpic.588ku.com%2Fback_pic%2F00%2F09%2F47%2F77562eea631a31c.jpg';
#
#                 var option_aa8f52164be04b8f8044948b400d4a71 = {
#     "backgroundColor": {
#         "type": "pattern",
#         "image": img,
#         "repeat": "no-repeat"
#     },
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5468\u8fb9\u51b7\u996e\u5e97\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 65.5,
#                 64.15811965811966,
#                 135.5137614678899,
#                 107.84745762711864,
#                 139.04624277456648,
#                 84.00657894736842,
#                 50.958333333333336,
#                 116.56944444444444,
#                 77.01515151515152,
#                 93.54838709677419,
#                 50.23770491803279,
#                 51.26271186440678,
#                 83.96116504854369,
#                 142.8,
#                 61.089285714285715,
#                 67.72,
#                 71.02127659574468,
#                 49.15555555555556,
#                 117.63636363636364,
#                 74.3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "insideRight",
#                 "margin": 8,
#                 "fontStyle": "italic"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u57ce\u5e02\u95e8\u5e97\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 342,
#                 234,
#                 218,
#                 177,
#                 173,
#                 152,
#                 144,
#                 144,
#                 132,
#                 124,
#                 122,
#                 118,
#                 103,
#                 80,
#                 56,
#                 50,
#                 47,
#                 45,
#                 44,
#                 40
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "insideRight",
#                 "margin": 8,
#                 "fontStyle": "italic"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5468\u8fb9\u51b7\u996e\u5e97\u6570\u91cf",
#                 "\u57ce\u5e02\u95e8\u5e97\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u5468\u8fb9\u51b7\u996e\u5e97\u6570\u91cf": true,
#                 "\u57ce\u5e02\u95e8\u5e97\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 45,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77\u5e02",
#                 "\u676d\u5dde\u5e02",
#                 "\u5e7f\u5dde\u5e02",
#                 "\u5b81\u6ce2\u5e02",
#                 "\u6df1\u5733\u5e02",
#                 "\u5357\u4eac\u5e02",
#                 "\u82cf\u5dde\u5e02",
#                 "\u6210\u90fd\u5e02",
#                 "\u798f\u5dde\u5e02",
#                 "\u6b66\u6c49\u5e02",
#                 "\u5317\u4eac\u5e02",
#                 "\u65e0\u9521\u5e02",
#                 "\u957f\u6c99\u5e02",
#                 "\u91cd\u5e86\u5e02",
#                 "\u5408\u80a5\u5e02",
#                 "\u9752\u5c9b\u5e02",
#                 "\u6e29\u5dde\u5e02",
#                 "\u5357\u901a\u5e02",
#                 "\u91d1\u534e\u5e02",
#                 "\u5e38\u5dde\u5e02"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "1\u70b9\u70b9\u95e8\u5e97\u6700\u591a20\u4e2a\u57ce\u5e02\u4e0e\u5468\u8fb9\u51b7\u996e\u5e97\u6570\u91cf",
#             "subtext": "\u6570\u636e\u622a\u6b62\u65e5\u671f\uff1a2020\u5e748\u6708",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_aa8f52164be04b8f8044948b400d4a71.setOption(option_aa8f52164be04b8f8044948b400d4a71);
#         });
#     </script>

# %%
# 1点点
from pyecharts.charts import Geo
from pyecharts.globals import ChartType

ydd_map = df.groupby(by='city').count().sort_values(by='id',ascending=False)['id']

g = Geo(init_opts=opts.InitOpts(theme=ThemeType.DARK, width='1000px', height='700px'))
g.add_schema(maptype="china")
g.add("1dd", 
      [list(z) for z in zip(ydd_map.index, ydd_map.values.tolist())],
     type_=ChartType.EFFECT_SCATTER,)  
g.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
g.set_global_opts(
       
        visualmap_opts=opts.VisualMapOpts(is_piecewise=False, min_=3,max_=150),
        title_opts=opts.TitleOpts(title="1dd全国门店城市分布图"),
        
    )
g.render_notebook()
# Out:
# D:\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="5c2339b2996547ef8cef685fc1c3be1e" style="width:1000px; height:700px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_5c2339b2996547ef8cef685fc1c3be1e = echarts.init(
#                     document.getElementById('5c2339b2996547ef8cef685fc1c3be1e'), 'dark', {renderer: 'canvas'});
#                 var option_5c2339b2996547ef8cef685fc1c3be1e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "1dd",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         121.47,
#                         31.23,
#                         342
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde\u5e02",
#                     "value": [
#                         120.15,
#                         30.28,
#                         234
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": [
#                         113.27,
#                         23.13,
#                         218
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u6ce2\u5e02",
#                     "value": [
#                         121.55,
#                         29.88,
#                         177
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733\u5e02",
#                     "value": [
#                         114.05,
#                         22.55,
#                         173
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac\u5e02",
#                     "value": [
#                         118.78,
#                         32.07,
#                         152
#                     ]
#                 },
#                 {
#                     "name": "\u82cf\u5dde\u5e02",
#                     "value": [
#                         120.58,
#                         31.3,
#                         144
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd\u5e02",
#                     "value": [
#                         104.07,
#                         30.67,
#                         144
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5dde\u5e02",
#                     "value": [
#                         119.3,
#                         26.08,
#                         132
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49\u5e02",
#                     "value": [
#                         114.3,
#                         30.6,
#                         124
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         122
#                     ]
#                 },
#                 {
#                     "name": "\u65e0\u9521\u5e02",
#                     "value": [
#                         120.3,
#                         31.57,
#                         118
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99\u5e02",
#                     "value": [
#                         112.93,
#                         28.23,
#                         103
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": [
#                         106.55,
#                         29.57,
#                         80
#                     ]
#                 },
#                 {
#                     "name": "\u5408\u80a5\u5e02",
#                     "value": [
#                         117.25,
#                         31.83,
#                         56
#                     ]
#                 },
#                 {
#                     "name": "\u9752\u5c9b\u5e02",
#                     "value": [
#                         120.38,
#                         36.07,
#                         50
#                     ]
#                 },
#                 {
#                     "name": "\u6e29\u5dde\u5e02",
#                     "value": [
#                         120.7,
#                         28,
#                         47
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u901a\u5e02",
#                     "value": [
#                         120.88,
#                         31.98,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u91d1\u534e\u5e02",
#                     "value": [
#                         119.65,
#                         29.08,
#                         44
#                     ]
#                 },
#                 {
#                     "name": "\u5e38\u5dde\u5e02",
#                     "value": [
#                         119.95,
#                         31.78,
#                         40
#                     ]
#                 },
#                 {
#                     "name": "\u5609\u5174\u5e02",
#                     "value": [
#                         120.75,
#                         30.75,
#                         39
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde\u5e02",
#                     "value": [
#                         113.62,
#                         34.75,
#                         39
#                     ]
#                 },
#                 {
#                     "name": "\u6cc9\u5dde\u5e02",
#                     "value": [
#                         118.67,
#                         24.88,
#                         37
#                     ]
#                 },
#                 {
#                     "name": "\u53f0\u5dde\u5e02",
#                     "value": [
#                         121.43,
#                         28.68,
#                         34
#                     ]
#                 },
#                 {
#                     "name": "\u626c\u5dde\u5e02",
#                     "value": [
#                         119.4,
#                         32.4,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "\u76d0\u57ce\u5e02",
#                     "value": [
#                         120.15,
#                         33.35,
#                         26
#                     ]
#                 },
#                 {
#                     "name": "\u6dee\u5b89\u5e02",
#                     "value": [
#                         119.02,
#                         33.62,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u7ecd\u5174\u5e02",
#                     "value": [
#                         120.57,
#                         30,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u9547\u6c5f\u5e02",
#                     "value": [
#                         119.45,
#                         32.2,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89\u5e02",

# %%
# 数据格式

df
# Out:
#       Unnamed: 0 city                    id          title  \
# 0              0  漯河市   6820359242544590282     1点点(旺发大厦店)
# 1              0  许昌市   5656666522409923468     1点点(裕华大街店)
# 2              0  信阳市   3501326798700902669     1点点(天润广场店)
# 3              1  信阳市   6259220003815133167     1点点(胜利北路店)
# 4              2  信阳市   9451597071632913476      1点点(北大街店)
# ...          ...  ...                   ...            ...
# 3262           0  北京市  10212695062286682003  1点点(东柏街10号院店)
# 3263           1  北京市   1282374550049674913       1点点(锐创店)
# 3264           2  北京市  15702436170419907631     1点点(朝阳公园店)
# 3265           3  北京市  10342966570133162090      1点点(大世界店)
# 3266           0  临汾市  16635617383907838929     1点点(青狮北街店)
#
#                           address           tel category  type  \
# 0     河南省漯河市源汇区交通路中段旺发大厦楼下正北方向12米                 美食:冷饮店     0
# 1       河南省许昌市禹州市颍川街道裕华大街中段北侧280号   17737282777   美食:冷饮店     0
# 2          河南省信阳市浉河区万家灯火城市广场商业步行街   15229305666   美食:冷饮店     0
# 3         河南省信阳市浉河区胜北路步行街胜利北路129号                 美食:冷饮店     0
# 4              河南省信阳市息县城关镇北大街161号                 美食:冷饮店     0
# ...                           ...           ...      ...   ...
# 3262        北京市朝阳区东柏街天子骄子9号院2号楼底商   18514202030   美食:冷饮店     0
# 3263        北京市朝阳区新苑路4号锐创大厦1层102A  010-65000203   美食:冷饮店     0
# 3264   北京市朝阳区朝阳公园骏豪·中央公园广场A1座B150                 美食:冷饮店     0
# 3265           北京市怀柔区府前街12号1幢一层3号   13341115602   美食:冷饮店     0
# 3266                山西省临汾市尧都区青狮北街                 美食:冷饮店     0
#
#                                    location  \
# 0     {'lat': 33.571201, 'lng': 114.038601}
# 1     {'lat': 34.147033, 'lng': 113.494766}
# 2     {'lat': 32.126423, 'lng': 114.080561}
# 3      {'lat': 32.123311, 'lng': 114.07557}
# 4     {'lat': 32.344611, 'lng': 114.738851}
# ...                                     ...
# 3262  {'lat': 39.895413, 'lng': 116.465541}
# 3263  {'lat': 39.918315, 'lng': 116.463283}
# 3264  {'lat': 39.932783, 'lng': 116.477456}
# 3265  {'lat': 40.315764, 'lng': 116.633363}
# 3266  {'lat': 36.080591, 'lng': 111.521755}
#
#                                                 ad_info  nearbyStoreCount
# 0     {'adcode': 411102, 'province': '河南省', 'city': ...               117
# 1     {'adcode': 411081, 'province': '河南省', 'city': ...                53
# 2     {'adcode': 411502, 'province': '河南省', 'city': ...               106
# 3     {'adcode': 411502, 'province': '河南省', 'city': ...               138
# 4     {'adcode': 411528, 'province': '河南省', 'city': ...                50
# ...                                                 ...               ...
# 3262  {'adcode': 110105, 'province': '北京市', 'city': ...                74
# 3263  {'adcode': 110105, 'province': '北京市', 'city': ...               120
# 3264  {'adcode': 110105, 'province': '北京市', 'city': ...                14
# 3265  {'adcode': 110116, 'province': '北京市', 'city': ...                39
# 3266  {'adcode': 141002, 'province': '山西省', 'city': ...               126
#
# [3267 rows x 11 columns]
